# %%
import tensorflow as tf
import json

def load_jsonl(path):
    ds = tf.data.TextLineDataset(path)

    def parse_line(line):
        obj = tf.py_function(lambda s: json.loads(s.numpy()), [line], Tout=tf.string)
        return obj

    return ds

dataset = load_jsonl("mixed_dataset.jsonl")
# Out:
# 2025-11-21 17:15:46.948563: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763725545.959142    4958 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763725545.992891    4958 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763725546.288058    4958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763725546.288217    4958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763725546.288220    4958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763725546.288223    4958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-21 17:15:46.321290: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1763725552.437550    4958 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4055 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
import sentencepiece as spm

spm.SentencePieceTrainer.Train(
    input='mixed_dataset.jsonl',
    model_prefix='tinyllm',
    vocab_size=16000,
    character_coverage=1.0,
    model_type='bpe',
    pad_id=0,
    unk_id=1,
    bos_id=2,
    eos_id=3,
    user_defined_symbols=["<user>:", "<assistant>:"]
)

print("Tokenizer trained: tinyllm.model, tinyllm.vocab")
# Out:
# Tokenizer trained: tinyllm.model, tinyllm.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: mixed_dataset.jsonl
#   input_format:
#   model_prefix: tinyllm
#   model_type: BPE
#   vocab_size: 16000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <user>:
#   user_defined_symbols: <assistant>:
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: mixed_dataset.jsonl
# trainer_interface.cc(382) LOG(WARNING) Found too long line (7671 > 4192).
# trainer_interface.cc(384) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(385) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(411) LOG(INFO) Loaded all 54990 sentences
# trainer_interface.cc(418) LOG(INFO) Skipped 484 too long sentences.
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <user>:
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <assistant>:
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=47640065
# trainer_interface.cc(552) LOG(INFO) Done: 100% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=5666
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 54990 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 54990
# trainer_interface.cc(611) LOG(INFO) Done! 649707
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=713979 min_freq=56
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=242787 size=20 all=89442 active=6263 piece=▁m
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=157457 size=40 all=91262 active=8083 piece=ent
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91646 size=60 all=93532 active=10353 piece=et
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65465 size=80 all=95731 active=12552 piece=▁la
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54992 size=100 all=97997 active=14818 piece=":
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=54992 min_freq=334
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47200 size=120 all=99729 active=6630 piece=th
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38160 size=140 all=101805 active=8706 piece=."}
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32910 size=160 all=103889 active=10790 piece=▁tr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27582 size=180 all=106650 active=13551 piece=▁pr
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23587 size=200 all=108334 active=15235 piece=act
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=214 size=9540 all=355115 active=18257 piece=close
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=214 size=9560 all=355184 active=18326 piece=▁eficiencia
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=213 size=9580 all=355486 active=18628 piece=▁Aseg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=213 size=9600 all=355551 active=18693 piece=▁inicial
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=213 min_freq=57
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=212 size=9620 all=355981 active=18198 piece=eted
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=212 size=9640 all=356182 active=18399 piece=▁связа
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=211 size=9660 all=356315 active=18532 piece=рак
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=211 size=9680 all=356485 active=18702 piece=▁simulation
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=210 size=9700 all=356912 active=19129 piece=▁closed
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=210 min_freq=56
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=209 size=9720 all=357159 active=18093 piece=обще
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=209 size=9740 all=357352 active=18286 piece=▁Development
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=208 size=9760 all=357495 active=18429 piece=▁suma
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=207 size=9780 all=357711 active=18645 piece=nHe
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=207 size=9800 all=357969 active=18903 piece=▁región
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=207 min_freq=56
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=206 size=9820 all=358366 active=18296 piece=New
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=206 size=9840 all=358747 active=18677 piece=▁Empire
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=205 size=9860 all=358759 active=18689 piece=Pl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=205 size=9880 all=359332 active=19262 piece=▁Cada
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=205 size=9900 all=359398 active=19328 piece=▁actividad
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=205 min_freq=55
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=204 size=9920 all=359717 active=18289 piece=▁attend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=203 size=9940 all=359858 active=18430 piece=what
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=203 size=9960 all=360042 active=18614 piece=▁fulfill
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=202 size=9980 all=360361 active=18933 piece=▁26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=202 size=10000 all=360584 active=19156 piece=▁cardio
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=202 min_freq=54
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=201 size=10020 all=360789 active=18233 piece=▁Eas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=201 size=10040 all=360935 active=18379 piece=▁theme
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=200 size=10060 all=361237 active=18681 piece=▁PM
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=200 size=10080 all=361560 active=19004 piece=▁ratio
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=199 size=10100 all=362089 active=19533 piece=▁Sen
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=199 min_freq=54
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=199 size=10120 all=362340 active=18335 piece=▁eventos
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=198 size=10140 all=362564 active=18559 piece=▁пока
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=198 size=10160 all=362654 active=18649 piece=▁delivery
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=197 size=10180 all=363090 active=19085 piece=erme
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=197 size=10200 all=363274 active=19269 piece=▁hermos
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=197 min_freq=53
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=196 size=10220 all=363693 active=18577 piece=▁фак
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=196 size=10240 all=363808 active=18692 piece=▁authentic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=195 size=10260 all=364186 active=19070 piece=ского
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=195 size=10280 all=364276 active=19160 piece=▁ejercicio
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=194 size=10300 all=364627 active=19511 piece=uerdo
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=194 min_freq=53
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=193 size=10320 all=364858 active=18458 piece=PG
# trainer_interface.cc(689) LOG(INFO) Saving model: tinyllm.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: tinyllm.vocab

# %%
sp = spm.SentencePieceProcessor()
sp.load("tinyllm.model")

MAX_LEN = 384
PAD_ID = 0 if sp.pad_id() < 0 else sp.pad_id()

# %%
def encode_example(text):
    ids = sp.encode(text, out_type=int)

    if len(ids) > MAX_LEN:
        ids = ids[:MAX_LEN]

    x = ids[:-1]
    y = ids[1:]

    # pad
    x = x + [PAD_ID] * (MAX_LEN - len(x))
    y = y + [PAD_ID] * (MAX_LEN - len(y))

    return x, y

# %%
def tf_load_dataset(path, batch_size=8):
    ds = tf.data.TextLineDataset(path)

    def parse_json(line):
        obj = json.loads(line.numpy().decode("utf-8"))
        return obj["text"]

    def tf_parse_json(line):
        text = tf.py_function(parse_json, [line], Tout=tf.string)
        text.set_shape([])  # VERY IMPORTANT
        return text

    def tf_encode(text):
        x, y = tf.py_function(
            lambda t: encode_example(t.numpy().decode("utf-8")),
            [text],
            [tf.int32, tf.int32]
        )
        # Set shapes MANUALLY (the fix for your error)
        x.set_shape([MAX_LEN])
        y.set_shape([MAX_LEN])
        return x, y

    ds = ds.map(tf_parse_json, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.map(tf_encode, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.shuffle(20000)
    ds = ds.batch(batch_size, drop_remainder=True)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# %%
train_ds = tf_load_dataset("mixed_dataset.jsonl")

# %%
import tensorflow as tf

class DecoderBlock(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, d_ff):
        super().__init__()
        self.att = tf.keras.layers.MultiHeadAttention(num_heads, key_dim=d_model)
        self.ln1 = tf.keras.layers.LayerNormalization()
        self.ff = tf.keras.Sequential([
            tf.keras.layers.Dense(d_ff, activation="gelu"),
            tf.keras.layers.Dense(d_model)
        ])
        self.ln2 = tf.keras.layers.LayerNormalization()

    def call(self, x, causal_mask):
        attn = self.att(x, x, attention_mask=causal_mask)
        x = self.ln1(x + attn)
        ff_out = self.ff(x)
        return self.ln2(x + ff_out)

def build_model(vocab_size=16000, max_len=256, d_model=384, layers=4, heads=6):
    inputs = tf.keras.Input(shape=(max_len,), dtype=tf.int32)

    embed = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)


    pos = tf.range(max_len)[tf.newaxis, :]
    pos_embed = tf.keras.layers.Embedding(max_len, d_model)(pos)
    x = embed + pos_embed

    mask = tf.linalg.band_part(tf.ones((max_len, max_len)), -1, 0)
    mask = mask[tf.newaxis, tf.newaxis, :, :]

    for _ in range(layers):
        x = DecoderBlock(d_model, heads, d_ff=4 * d_model)(x, mask)

    logits = tf.keras.layers.Dense(vocab_size)(x)

    model = tf.keras.Model(inputs, logits)
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "functional_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_21 (InputLayer)     │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_6 (Embedding)         │ (None, 256, 384)       │     6,144,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_3 (Add)                     │ (None, 256, 384)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_block_18 (DecoderBlock) │ (None, 256, 384)       │     4,729,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_block_19 (DecoderBlock) │ (None, 256, 384)       │     4,729,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_block_20 (DecoderBlock) │ (None, 256, 384)       │     4,729,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_block_21 (DecoderBlock) │ (None, 256, 384)       │     4,729,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_block_22 (DecoderBlock) │ (None, 256, 384)       │     4,729,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_block_23 (DecoderBlock) │ (None, 256, 384)       │     4,729,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 256, 16000)     │     6,160,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,680,064 (155.18 MB)
#  Trainable params: 40,680,064 (155.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=3e-4)

model.compile(
    optimizer=optimizer,
    loss=loss_fn
)

model.fit(
    train_ds,
    epochs=10
)
# Out:
# Epoch 1/3
# 2025-11-21 20:05:27.903155: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:35: Filling up shuffle buffer (this may take a while): 5488 of 20000
# 2025-11-21 20:05:47.900474: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:35: Filling up shuffle buffer (this may take a while): 16784 of 20000
# 2025-11-21 20:05:52.139439: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# 2025-11-21 20:06:01.565706: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion', 72 bytes spill stores, 72 bytes spill loads
# 6934/6934 ━━━━━━━━━━━━━━━━━━━━ 1129s 155ms/step - loss: 5.2475
# Epoch 2/3
# 2025-11-21 20:23:53.738025: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 7346126858096581346
# 2025-11-21 20:24:03.787420: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:35: Filling up shuffle buffer (this may take a while): 5615 of 20000
# 2025-11-21 20:24:23.786360: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:35: Filling up shuffle buffer (this may take a while): 17169 of 20000
# 2025-11-21 20:24:29.259591: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# 6934/6934 ━━━━━━━━━━━━━━━━━━━━ 1103s 154ms/step - loss: 5.6235
# Epoch 3/3
# 2025-11-21 20:42:16.724775: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_4]]
# 2025-11-21 20:42:16.724835: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 7346126858096581346
# 2025-11-21 20:42:16.724846: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 11863766883536092728
# 2025-11-21 20:42:26.762997: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:35: Filling up shuffle buffer (this may take a while): 5668 of 20000
# 2025-11-21 20:42:46.759304: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:35: Filling up shuffle buffer (this may take a while): 17787 of 20000
# 2025-11-21 20:42:51.177063: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# 6934/6934 ━━━━━━━━━━━━━━━━━━━━ 1100s 154ms/step - loss: 5.6190
# 2025-11-21 21:00:37.043210: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 7346126858096581346
# 2025-11-21 21:00:37.043264: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 11863766883536092728

# %%
model.save('checkpoints/model_fixed_3.keras')

# %%
def generate(prompt, max_new=50):
    ids = sp.encode(prompt, out_type=int)
    
    for _ in range(max_new):
        x = ids[-256:]
        pad = [sp.pad_id()] * (256 - len(x))
        x = pad + x
        x = tf.constant([x])

        seq_len = len(ids)
        logits = model(x)[0, x.shape[1] - 1]  
        next_id = int(tf.argmax(logits))
        ids.append(next_id)

        if next_id == sp.eos_id():
            break

    return sp.decode(ids)

print(generate("<user>: hey\n<assistant>:"))
# Out:
# <user>: hey <assistant>:
